# %%
def smallest(inp) :
# function to make the smallest number from digits
    cloop = 0
    slen=0
    mcount = 0
    scount=0
    sort = []
    n_num = []
    small = 0
    ind = 0
# set main counter
    olen = len(inp) 
    slen = len(inp)
    olist = list(inp)
    while mcount<olen :
        small = int(olist[cloop])
        while scount< (slen-1):
            if  small > int(olist[scount+1]) :
                small = int(olist[scount+1])
                ind = scount+1
                scount = ind
            else:
                scount = scount+1
        n_num.append(small)
        mcount = mcount+1
        scount=0
        del(olist[ind])
        ind = 0
        slen=len(olist)
        if slen == 1:
            n_num.append(olist[0])
            mcount = mcount+1
            break
    return n_num    

def largest(inp) :
# function to make the smallest number from digits
    cloop = 0
    slen=0
    mcount = 0
    scount=0
    sort = []
    n_num = []
    large = 0
    ind = 0
# set main counter
    olen = len(inp) 
    slen = len(inp)
    olist = list(inp)
    while mcount<olen :
        large = int(olist[cloop])
        while scount< (slen-1):
            if  large < int(olist[scount+1]) :
                large = int(olist[scount+1])
                ind = scount+1
                scount = ind
            else:
                scount = scount+1
        n_num.append(large)
        mcount = mcount+1
        scount=0
        del(olist[ind])
        ind = 0
        slen=len(olist)
        if slen == 1:
            n_num.append(olist[0])
            mcount = mcount+1
            break
    return n_num  
number = []    

inp = input("Hi input Number: ")  

snumber = smallest(inp)  
small_stri = ''.join(map(str,snumber))

lnumber = largest(inp)  
large_stri = ''.join(map(str,lnumber))

print("Smallest Number that could be formed using these digits is: ",small_stri)
print("Largest Number that could be formed using these digits is: ",large_stri)
